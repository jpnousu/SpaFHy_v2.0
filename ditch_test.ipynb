# %%
from iotools import write_AsciiGrid, read_AsciiGrid
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cbook as cbook
from matplotlib import cm

# %%
ditches_raw = r'/SpaFHy_v1_Pallas_2D/testcase_input/parameters/ditches.dat'
flowacc_raw = r'/SpaFHy_v1_Pallas_2D/testcase_input/parameters/flowacc.dat'

d = read_AsciiGrid(ditches_raw)
f = read_AsciiGrid(flowacc_raw)

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(12,5));
ax1 = axs[0]
ax2 = axs[1]
ax3 = axs[2]

im1 = ax1.imshow(f[0], norm=colors.LogNorm())
fig.colorbar(im1)

ax2.imshow(f[0][20:250,20:175], vmin=4000, vmax=4001)

ax3.imshow(d[0][20:250,20:175])

# %%
# Out:
# (array([1.5547e+04, 4.5400e+02, 1.6200e+02, 9.7000e+01, 6.5000e+01,
#         3.9000e+01, 1.5000e+01, 7.0000e+00, 8.0000e+00, 9.0000e+00,
#         6.0000e+00, 7.0000e+00, 1.1000e+01, 7.0000e+00, 6.0000e+00,
#         9.0000e+00, 3.0000e+00, 5.0000e+00, 0.0000e+00, 1.0000e+00,
#         2.0000e+00, 2.0000e+00, 3.0000e+00, 4.0000e+00, 3.0000e+00,
#         1.0000e+00, 2.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00,
#         0.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 3.0000e+00,
#         5.0000e+00, 9.0000e+00, 7.0000e+00, 3.0000e+00, 2.0000e+00,
#         2.0000e+00, 2.0000e+00, 5.0000e+00, 3.0000e+00, 2.0000e+00,
#         4.0000e+00, 2.0000e+00, 3.0000e+00, 4.0000e+00, 1.0000e+00,
#         2.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
#         0.0000e+00, 4.0000e+00, 1.4000e+01, 1.2000e+01, 4.0000e+00,
#         2.0000e+00, 6.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
# ...
