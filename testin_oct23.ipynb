# %%
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file = r'F:\SpaFHy_2D_2021\testcase_input_202310181320.nc'
res = xr.open_dataset(file)

# defining important raster locations
ht = [118,136] # hilltop
om = [46, 54]   # open mire

# %%
gw_file = r'/SpaFHy_v1_Pallas_2D/obs/gw_levels.csv'
gw = pd.read_csv(gw_file, sep=';',index_col=0, parse_dates=True)

# %%
gw.plot()
# Out:
# <Axes: xlabel='time'>

# %%
res['soil_ground_water_level'][:,om[0],om[1]].plot()
res['soil_ground_water_level'][:,ht[0],ht[1]].plot()
