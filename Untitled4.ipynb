# %%
import pandas as pd

# %%
file = r'C:\Users\janousu\OneDrive - Oulun yliopisto\Pallas data\DATABASE\AET\Kenttarova\FINAL\Kenttarova_AET_daily_2003-2018.txt'

# %%
test = pd.read_csv(file, sep=';', encoding='latin-1', skiprows=10, index_col=0, parse_dates=True)

# %%
test[' AET_tight']['2013-09-01':'2018-01-01'].plot()
# Out:
# <Axes: xlabel='Date'>
